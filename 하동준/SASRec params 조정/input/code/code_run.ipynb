# %%
# !python run_pretrain.py
# Out:
# Total Parameters: 7746496
# Pretrain-Ml Epoch:0: 100%|| 3045/3045 [06:24<00:00,  7.92it/s]
# AAP-0.2-MIP-1.0-MAP-1.0-SP-0.5
# {'epoch': 0, 'aap_loss_avg': 12.551427002679343, 'mip_loss_avg': 2.001646567996108, 'map_loss_avg': 37.60115696291618, 'sp_loss_avg': 0.6368769037459284}
# Better performance. Saving model ...
# Pretrain-Ml Epoch:1: 100%|| 3045/3045 [06:20<00:00,  8.00it/s]
# AAP-0.2-MIP-1.0-MAP-1.0-SP-0.5
# {'epoch': 1, 'aap_loss_avg': 1.1491656919418298, 'mip_loss_avg': 1.961988049657474, 'map_loss_avg': 37.15489878975503, 'sp_loss_avg': 0.5928643137510187}
# Better performance. Saving model ...
# Pretrain-Ml Epoch:2: 100%|| 3045/3045 [06:21<00:00,  7.99it/s]
# AAP-0.2-MIP-1.0-MAP-1.0-SP-0.5
# {'epoch': 2, 'aap_loss_avg': 0.8959573753019076, 'mip_loss_avg': 1.9502118317560218, 'map_loss_avg': 37.08272486281121, 'sp_loss_avg': 0.5837541992343314}
# Better performance. Saving model ...
# Pretrain-Ml Epoch:3: 100%|| 3045/3045 [06:18<00:00,  8.06it/s]
# ...

# %%
# !python run_train.py
# Out:
# Namespace(adam_beta1=0.9, adam_beta2=0.98, attention_probs_dropout_prob=0.2, attribute_size=18, batch_size=128, cuda_condition=True, data_dir='../data/train/', data_file='../data/train/train_ratings.csv', data_name='Ml', epochs=201, gpu_id='0', hidden_act='gelu', hidden_dropout_prob=0.2, hidden_size=64, initializer_range=0.02, item_size=119147, log_file='output/Finetune_full-Ml.txt', log_freq=1, lr=0.001, mask_id=119146, max_seq_length=200, model_name='Finetune_full', no_cuda=False, num_attention_heads=8, num_hidden_layers=2, output_dir='output/', seed=42, using_pretrain=False, weight_decay=0.0)
# Total Parameters: 7756096
# False
# Not using pretrained model. The Model is same as SASRec
# Recommendation EP_train:0: 100%|| 245/245 [00:16<00:00, 14.84it/s]
# {'epoch': 0, 'rec_avg_loss': '0.4347', 'rec_cur_loss': '0.1794'}
# Recommendation EP_valid:0: 100%|| 245/245 [01:19<00:00,  3.08it/s]
# ...

# %%
# !python inference.py
# Out:
# Namespace(adam_beta1=0.9, adam_beta2=0.98, attention_probs_dropout_prob=0.2, attribute_size=18, batch_size=128, cuda_condition=True, data_dir='../data/train/', data_file='../data/train/train_ratings.csv', data_name='Ml', do_eval=False, epochs=201, gpu_id='0', hidden_act='gelu', hidden_dropout_prob=0.2, hidden_size=64, initializer_range=0.02, item_size=119147, log_freq=1, lr=0.001, mask_id=119146, max_seq_length=200, model_name='Finetune_full', no_cuda=False, num_attention_heads=8, num_hidden_layers=2, output_dir='output/', seed=42, weight_decay=0.0)
# Total Parameters: 7756096
# Load model from output/Finetune_full-Ml.pt for submission!
# Recommendation EP_submission:0: 100%|| 245/245 [01:28<00:00,  2.76it/s]
